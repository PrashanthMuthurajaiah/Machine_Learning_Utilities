# %%
from IPython.display import Image

# %%
Image(filename='./Images/MR1.png')

# %%
Image(filename='./Images/MR2.png')

# %%
Image(filename='./Images/MR3.png')

# %%
Image(filename='./Images/MR4.png')
